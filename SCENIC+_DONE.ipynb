# %%
# !conda --version
# !which python
# !python --version
# !echo $PYTHONPATH
# %env PYTHONPATH=
# Out:
# /bin/bash: line 1: conda: command not found
# /usr/local/bin/python
# Python 3.10.12
# /env/python
# env: PYTHONPATH=

# %%
# !wget https://repo.anaconda.com/miniconda/Miniconda3-py37_4.12.0-Linux-x86_64.sh
# !chmod +x Miniconda3-py37_4.12.0-Linux-x86_64.sh
# !bash ./Miniconda3-py37_4.12.0-Linux-x86_64.sh -b -f -p /usr/local/
# Out:
# --2024-07-25 12:39:26--  https://repo.anaconda.com/miniconda/Miniconda3-py37_4.12.0-Linux-x86_64.sh
# Resolving repo.anaconda.com (repo.anaconda.com)... 104.16.191.158, 104.16.32.241, 2606:4700::6810:20f1, ...
# Connecting to repo.anaconda.com (repo.anaconda.com)|104.16.191.158|:443... connected.
# HTTP request sent, awaiting response... 200 OK
# Length: 104996770 (100M) [application/x-sh]
# Saving to: ‘Miniconda3-py37_4.12.0-Linux-x86_64.sh.1’
#
# Miniconda3-py37_4.1 100%[===================>] 100.13M   100MB/s    in 1.0s
#
# 2024-07-25 12:39:27 (100 MB/s) - ‘Miniconda3-py37_4.12.0-Linux-x86_64.sh.1’ saved [104996770/104996770]
#
# PREFIX=/usr/local
# Unpacking payload ...
# done
# done
#
# ## Package Plan ##
#
#   environment location: /usr/local
#
#   added / updated specs:
#     - _libgcc_mutex==0.1=main
#     - _openmp_mutex==4.5=1_gnu
#     - brotlipy==0.7.0=py37h27cfd23_1003
#     - ca-certificates==2022.3.29=h06a4308_1
#     - certifi==2021.10.8=py37h06a4308_2
# ...

# %%
# !conda --version
# !python --version
# Out:
# conda 4.12.0
# Python 3.7.13

# %%
# !conda install --channel defaults conda python=3.11 --yes #put python version of interest
# Out:
# done
# failed with initial frozen solve. Retrying with flexible solve.
# failed with repodata from current_repodata.json, will retry with next repodata source.
# done
# done
#
# ## Package Plan ##
#
#   environment location: /usr/local
#
#   added / updated specs:
#     - conda
#     - python=3.11
#
#
# The following packages will be downloaded:
#
#     package                    |            build
#     ---------------------------|-----------------
#     boltons-23.0.0             |  py311h06a4308_0         477 KB
#     brotlipy-0.7.0             |py311h5eee18b_1002         307 KB
#     bzip2-1.0.8                |       h5eee18b_6         262 KB
#     ca-certificates-2024.7.2   |       h06a4308_0         127 KB
#     certifi-2024.7.4           |  py311h06a4308_0         159 KB
#     cffi-1.16.0                |  py311h5eee18b_1         313 KB
#     conda-23.9.0               |  py311h06a4308_0         1.3 MB
#     conda-package-handling-2.3.0|  py311h06a4308_0         281 KB
# ...

# %%
# !conda --version
# !python --version
# Out:
# conda 23.9.0
# Python 3.11.0

# %%
# !ls -l /usr/local/lib | grep '^d.*python*' # check the python version of interest
# Out:
# drwxr-xr-x  1 root root     4096 Jul 23 13:12 python3.10
# drwxr-xr-x 39 root root    12288 Jul 25 12:41 python3.11

# %%
import sys
sys.path.append("/usr/local/lib/python3.11/site-packages") # fill the python of interest

# %%
# !git clone https://github.com/aertslab/scenicplus
# Out:
# Cloning into 'scenicplus'...
# remote: Enumerating objects: 3523, done.
# remote: Counting objects: 100% (833/833), done.
# remote: Compressing objects: 100% (316/316), done.
# remote: Total 3523 (delta 460), reused 743 (delta 405), pack-reused 2690
# Receiving objects: 100% (3523/3523), 44.55 MiB | 25.61 MiB/s, done.
# Resolving deltas: 100% (1961/1961), done.

# %%
import os
os.chdir("scenicplus")
# !pwd
# Out:
# /content/scenicplus

# %%
# !pip install .
# Out:
# Processing /content/scenicplus
#   Installing build dependencies ... done
#   Getting requirements to build wheel ... done
#   Preparing metadata (pyproject.toml) ... done
# ...
#   Cloning https://github.com/aertslab/LoomXpy (to revision main) to /tmp/pip-install-ziqefppg/loomxpy_23a771b066734468ad2f2e5ff6d4ebf7
#   Running command git clone --filter=blob:none --quiet https://github.com/aertslab/LoomXpy /tmp/pip-install-ziqefppg/loomxpy_23a771b066734468ad2f2e5ff6d4ebf7
#   Resolved https://github.com/aertslab/LoomXpy to commit 61995ff10940968eac2cee8fe48300ab477a15d0
#   Installing build dependencies ... done
#   Getting requirements to build wheel ... done
#   Preparing metadata (pyproject.toml) ... done
# ...
#   Cloning https://github.com/aertslab/pycistarget to /tmp/pip-install-ziqefppg/pycistarget_c5237f3c87b44b799baf01f6e4648de9
# ...

# %%
# Restart kernel
import os
os.kill(os.getpid(), 9)

# %%
import sys
sys.path.append("/usr/local/lib/python3.11/site-packages") # fill the python of interest

# %%
import scenicplus
