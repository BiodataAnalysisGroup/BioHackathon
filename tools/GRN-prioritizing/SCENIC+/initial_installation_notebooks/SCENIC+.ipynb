# %%
# !conda --version
# !which python
# !python --version
# !echo $PYTHONPATH
# %env PYTHONPATH=

# %%
# !wget https://repo.anaconda.com/miniconda/Miniconda3-py37_4.12.0-Linux-x86_64.sh
# !chmod +x Miniconda3-py37_4.12.0-Linux-x86_64.sh
# !bash ./Miniconda3-py37_4.12.0-Linux-x86_64.sh -b -f -p /usr/local/

# %%
# !conda install --channel defaults conda python=3.11 --yes #only python 3.11 works with SCENIC+

# %%
# !conda --version
# !python --version

# %%
# !ls -l /usr/local/lib | grep '^d.*python*' #only python 3.11 works with SCENIC+

# %%
import sys
sys.path.append("/usr/local/lib/python3.11/site-packages") #only python 3.11 works with SCENIC+

# %%
# !git clone https://github.com/aertslab/scenicplus

# %%
import os
os.chdir("scenicplus")
# !pwd

# %%
# !pip install .

# %%
# Restart kernel
import os
os.kill(os.getpid(), 9)

# %%
import sys
sys.path.append("/usr/local/lib/python3.11/site-packages") #only python 3.11 works with SCENIC+

# %%
import scenicplus
