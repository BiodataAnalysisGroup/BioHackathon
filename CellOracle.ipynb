# %%
# !conda --version
# !which python
# !python --version
# !echo $PYTHONPATH
# %env PYTHONPATH=
# Out:
# /bin/bash: line 1: conda: command not found
# /usr/local/bin/python
# Python 3.10.12
# /env/python
# env: PYTHONPATH=

# %%
# !wget https://repo.anaconda.com/miniconda/Miniconda3-py37_4.12.0-Linux-x86_64.sh
# !chmod +x Miniconda3-py37_4.12.0-Linux-x86_64.sh
# !bash ./Miniconda3-py37_4.12.0-Linux-x86_64.sh -b -f -p /usr/local/
# Out:
# --2024-07-25 12:39:51--  https://repo.anaconda.com/miniconda/Miniconda3-py37_4.12.0-Linux-x86_64.sh
# Resolving repo.anaconda.com (repo.anaconda.com)... 104.16.191.158, 104.16.32.241, 2606:4700::6810:20f1, ...
# Connecting to repo.anaconda.com (repo.anaconda.com)|104.16.191.158|:443... connected.
# HTTP request sent, awaiting response... 200 OK
# Length: 104996770 (100M) [application/x-sh]
# Saving to: ‘Miniconda3-py37_4.12.0-Linux-x86_64.sh’
#
# Miniconda3-py37_4.1 100%[===================>] 100.13M   179MB/s    in 0.6s
#
# 2024-07-25 12:39:52 (179 MB/s) - ‘Miniconda3-py37_4.12.0-Linux-x86_64.sh’ saved [104996770/104996770]
#
# PREFIX=/usr/local
# Unpacking payload ...
# done
# done
#
# ## Package Plan ##
#
#   environment location: /usr/local
#
#   added / updated specs:
#     - _libgcc_mutex==0.1=main
#     - _openmp_mutex==4.5=1_gnu
#     - brotlipy==0.7.0=py37h27cfd23_1003
#     - ca-certificates==2022.3.29=h06a4308_1
#     - certifi==2021.10.8=py37h06a4308_2
# ...

# %%
# !conda --version
# !python --version
# Out:
# conda 4.12.0
# Python 3.7.13

# %%
# !conda install --channel defaults conda python=3.10 --yes #put python version of interest
# Out:
# done
# failed with initial frozen solve. Retrying with flexible solve.
# failed with repodata from current_repodata.json, will retry with next repodata source.
# done
# done
#
# ## Package Plan ##
#
#   environment location: /usr/local
#
#   added / updated specs:
#     - conda
#     - python=3.10
#
#
# The following packages will be downloaded:
#
#     package                    |            build
#     ---------------------------|-----------------
#     boltons-23.0.0             |  py310h06a4308_0         430 KB
#     brotlipy-0.7.0             |py310h7f8727e_1002         712 KB
#     bzip2-1.0.8                |       h7b6447c_0          78 KB
#     ca-certificates-2024.7.2   |       h06a4308_0         127 KB
#     certifi-2024.7.4           |  py310h06a4308_0         158 KB
#     cffi-1.15.0                |  py310hd667e15_1         363 KB
#     conda-23.9.0               |  py310h06a4308_0         984 KB
#     conda-package-handling-2.3.0|  py310h06a4308_0         270 KB
# ...

# %%
# !conda --version
# !python --version
# Out:
# conda 23.9.0
# Python 3.10.4

# %%
# !ls -l /usr/local/lib | grep '^d.*python*' # check the python version of interest
# Out:
# drwxr-xr-x 1 root root    12288 Jul 25 12:41 python3.10

# %%
import sys
sys.path.append("/usr/local/lib/python3.10/site-packages") # fill the python of interest

# %%
# !git clone https://github.com/morris-lab/CellOracle.git
# Out:
# Cloning into 'CellOracle'...
# remote: Enumerating objects: 6030, done.
# remote: Counting objects: 100% (1076/1076), done.
# remote: Compressing objects: 100% (451/451), done.
# remote: Total 6030 (delta 615), reused 990 (delta 558), pack-reused 4954
# Receiving objects: 100% (6030/6030), 930.23 MiB | 23.99 MiB/s, done.
# Resolving deltas: 100% (3849/3849), done.
# Updating files: 100% (393/393), done.

# %%
import os
os.chdir("CellOracle")
# !pwd
# Out:
# /content/CellOracle

# %%
# !pip install --upgrade pip setuptools wheel
# Out:
# ...
#   Using cached pip-24.1.2-py3-none-any.whl.metadata (3.6 kB)
# ...
#   Using cached setuptools-71.1.0-py3-none-any.whl.metadata (6.6 kB)
# ...
#   Using cached wheel-0.43.0-py3-none-any.whl.metadata (2.2 kB)
# Using cached pip-24.1.2-py3-none-any.whl (1.8 MB)
# Using cached setuptools-71.1.0-py3-none-any.whl (2.3 MB)
# Using cached wheel-0.43.0-py3-none-any.whl (65 kB)
# ...
#   Attempting uninstall: wheel
#     Found existing installation: wheel 0.37.1
#     Uninstalling wheel-0.37.1:
#       Successfully uninstalled wheel-0.37.1
#   Attempting uninstall: setuptools
#     Found existing installation: setuptools 69.5.1
#     Uninstalling setuptools-69.5.1:
#       Successfully uninstalled setuptools-69.5.1
#   Attempting uninstall: pip
#     Found existing installation: pip 24.0
#     Uninstalling pip-24.0:
#       Successfully uninstalled pip-24.0
# ...

# %%
# !pip install numpy scipy pandas matplotlib loompy scikit-learn scikit-image statsmodels tensorflow keras pomegranate h5py networkx cython umap-learn seaborn pysam
# Out:
# ...
#   Using cached numpy-2.0.1-cp310-cp310-manylinux_2_17_x86_64.manylinux2014_x86_64.whl.metadata (60 kB)
# ...
#   Using cached scipy-1.14.0-cp310-cp310-manylinux_2_17_x86_64.manylinux2014_x86_64.whl.metadata (60 kB)
# ...
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 4.8/4.8 MB 40.8 MB/s eta 0:00:00
#   Preparing metadata (setup.py) ... done
# ...
#   Using cached scikit_learn-1.5.1-cp310-cp310-manylinux_2_17_x86_64.manylinux2014_x86_64.whl.metadata (12 kB)
# ...
#   Using cached h5py-3.11.0-cp310-cp310-manylinux_2_17_x86_64.manylinux2014_x86_64.whl.metadata (2.5 kB)
# ...
#   Using cached Cython-3.0.10-cp310-cp310-manylinux_2_17_x86_64.manylinux2014_x86_64.whl.metadata (3.2 kB)
# ...
#   Using cached seaborn-0.13.2-py3-none-any.whl.metadata (5.4 kB)
# ...
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 162.6/162.6 kB 9.7 MB/s eta 0:00:00
# ...
#   Using cached numba-0.60.0-cp310-cp310-manylinux2014_x86_64.manylinux_2_17_x86_64.whl.metadata (2.7 kB)
# ...
#   Using cached click-8.1.7-py3-none-any.whl.metadata (3.0 kB)
# ...

# %%
# !pip install velocyto==0.17.17
# Out:
# ...
#   Using cached velocyto-0.17.17.tar.gz (198 kB)
#   Preparing metadata (setup.py) ... done
# ...
#   Created wheel for velocyto: filename=velocyto-0.17.17-cp310-cp310-linux_x86_64.whl size=500452 sha256=5eff38d48f8f9a1abd0a7f83892bfcd72318bed5b0d649a80f5d04c0c5536ae8
#   Stored in directory: /root/.cache/pip/wheels/92/06/6f/f0c3c22504d969f129f594295619cda3fb650a6f7f5215e325
# Successfully built velocyto
# ...

# %%
# !pip install celloracle
# Out:
# ...
#   Using cached celloracle-0.18.0-py3-none-any.whl.metadata (4.0 kB)
# ...
#   Using cached matplotlib-3.6.3-cp310-cp310-manylinux_2_17_x86_64.manylinux2014_x86_64.whl.metadata (6.8 kB)
# ...
#   Using cached pandas-1.5.3-cp310-cp310-manylinux_2_17_x86_64.manylinux2014_x86_64.whl.metadata (11 kB)
# ...
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 12.2/12.2 MB 38.5 MB/s eta 0:00:00
#   Preparing metadata (setup.py) ... done
# ...
#   Preparing metadata (setup.py) ... done
# ...
#   Preparing metadata (setup.py) ... done
# ...
#   Preparing metadata (setup.py) ... done
# ...
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 12.6/12.6 MB 56.7 MB/s eta 0:00:00
#   Preparing metadata (setup.py) ... done
# ...
#   Preparing metadata (setup.py) ... done
# ...
#   Preparing metadata (setup.py) ... done
# ...
#   Using cached tomli-2.0.1-py3-none-any.whl.metadata (8.9 kB)
# ...
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 12.4/12.4 MB 54.3 MB/s eta 0:00:00
# ...
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 124.4/124.4 kB 7.8 MB/s eta 0:00:00
# ...

# %%
# Restart kernel
import os
os.kill(os.getpid(), 9)

# %%
import sys
sys.path.append("/usr/local/lib/python3.10/site-packages") # fill the python of interest

# %%
import celloracle as co
co.check_python_requirements()
# Out:
# /usr/local/lib/python3.10/site-packages/loompy/bus_file.py:68: NumbaDeprecationWarning: The 'nopython' keyword argument was not supplied to the 'numba.jit' decorator. The implicit default value for this argument is currently False, but it will be changed to True in Numba 0.59.0. See https://numba.readthedocs.io/en/stable/reference/deprecation.html#deprecation-of-object-mode-fall-back-behaviour-when-using-jit for details.
#   def twobit_to_dna(twobit: int, size: int) -> str:
# /usr/local/lib/python3.10/site-packages/loompy/bus_file.py:85: NumbaDeprecationWarning: The 'nopython' keyword argument was not supplied to the 'numba.jit' decorator. The implicit default value for this argument is currently False, but it will be changed to True in Numba 0.59.0. See https://numba.readthedocs.io/en/stable/reference/deprecation.html#deprecation-of-object-mode-fall-back-behaviour-when-using-jit for details.
#   def dna_to_twobit(dna: str) -> int:
# ...
